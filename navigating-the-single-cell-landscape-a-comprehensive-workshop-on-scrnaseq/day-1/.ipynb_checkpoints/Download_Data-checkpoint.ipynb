# %%
# %pip install --upgrade pip
# %pip install -U cellxgene_census
# Out:
# ...
#   Using cached cellxgene_census-1.10.2-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached tiledbsoma-1.7.2-cp311-cp311-macosx_10_14_x86_64.whl.metadata (5.3 kB)
# ...
#   Using cached typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached s3fs-2024.2.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached aiobotocore-2.11.2-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached aiohttp-3.9.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.4 kB)
# ...
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached somacore-1.0.7-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached tiledb-0.25.0.tar.gz (329 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pyarrow-12.0.1-cp311-cp311-macosx_10_14_x86_64.whl.metadata (3.0 kB)
# ...

# %%
import cellxgene_census

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.3 MB/s eta 0:00:0000:010:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.
